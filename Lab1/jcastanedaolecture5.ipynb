# %% [markdown]
# # Exercises: Plotting
# By Christopher van Hoecke, Max Margenot, and Delaney Mackenzie
#
# ## Lecture Link:
# https://www.quantopian.com/lectures/plotting-data
#
# ### IMPORTANT NOTE:
# This lecture corresponds to the Plotting Data lecture, which is part of the Quantopian lecture series. This homework expects you to rely heavily on the code presented in the corresponding lecture. Please copy and paste regularly from that lecture when starting to work on the problems, as trying to do them from scratch will likely be too difficult.
#
# Part of the Quantopian Lecture Series:
#
# * [www.quantopian.com/lectures](https://www.quantopian.com/lectures)
# * [github.com/quantopian/research_public](https://github.com/quantopian/research_public)
#
# ----

# %%
# Useful Functions
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ---

# %% [markdown]
# # Exercise 1:  Histograms
#
# ## a. Returns
# Find the daily returns for SPY over a 7-year window.

# %%
data = pd.read_csv("SPY.csv")
data1 = data.iloc[:, 4]
returns = data1.pct_change()[1:]

# %% [markdown]
# ## b. Graphing
# Using the techniques laid out in lecture, plot a histogram of the returns

# %%
plt.hist(returns, bins = 30)
plt.xlabel('Random Numbers')
plt.ylabel('Number of Times Observed')
plt.title('Frequency Distribution of randomly generated number')
# Out:
# Text(0.5,1,'Frequency Distribution of randomly generated number')

# %% [markdown]
# ## c. Cumulative distribution
# Plot the cumulative distribution histogram for your returns

# %%
plt.hist(returns, bins = 30, cumulative='true')
# Out:
# (array([1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 2.000e+00, 4.000e+00,
#         5.000e+00, 8.000e+00, 1.100e+01, 1.700e+01, 2.800e+01, 4.900e+01,
#         7.400e+01, 1.270e+02, 2.140e+02, 3.500e+02, 6.030e+02, 1.011e+03,
#         1.339e+03, 1.521e+03, 1.632e+03, 1.691e+03, 1.724e+03, 1.738e+03,
#         1.745e+03, 1.752e+03, 1.756e+03, 1.757e+03, 1.758e+03, 1.761e+03]),
#  array([-0.06512325, -0.0614025 , -0.05768175, -0.053961  , -0.05024026,
#         -0.04651951, -0.04279876, -0.03907801, -0.03535726, -0.03163651,
#         -0.02791576, -0.02419502, -0.02047427, -0.01675352, -0.01303277,
#         -0.00931202, -0.00559127, -0.00187052,  0.00185022,  0.00557097,
#          0.00929172,  0.01301247,  0.01673322,  0.02045397,  0.02417472,
#          0.02789546,  0.03161621,  0.03533696,  0.03905771,  0.04277846,
#          0.04649921]),
#  <a list of 30 Patch objects>)

# %% [markdown]
# ---

# %% [markdown]
# # Exercise 2 : Scatter Plots
#
# ## a. Data
# Start by collecting the close prices of McDonalds Corp. (MCD) and Starbucks (SBUX) for the last 5 years with daily frequency.

# %%
MCD = pd.read_csv("MCD.csv").iloc[:, 4]
SBUX = pd.read_csv("SBUX.csv").iloc[:, 4]

# %% [markdown]
# ## b. Plotting
# Graph a scatter plot of SPY and Starbucks.

# %%
plt.scatter(MCD, SBUX)
plt.title('Scatter plot of mcd and sbux')
plt.xlabel('MCD Price')
plt.ylabel('SBUX Price')
# Out:
# Text(0,0.5,'SBUX Price')

# %% [markdown]
# ## c. Plotting Returns
# Graph a scatter plot of the returns of SPY and Starbucks.

# %%
MCD_R = MCD.pct_change()[1:]
SBUX_R = SBUX.pct_change()[1:]

plt.scatter(MCD_R, SBUX_R);
plt.title('Scatter plot of mcd and starbucks returns');
plt.xlabel('SPY Return');
plt.ylabel('SBUX Return');

# %% [markdown]
# *Remember a scatter plot must have the same number of values for each parameter. If SPY and SBUX did not have the same number of data points, your graph will return an error*

# %% [markdown]
# ---

# %% [markdown]
# # Exercise 3 : Linear Plots
#
# ## a. Getting Data
# Use the techniques laid out in lecture to find the open price over a 2-year period for Starbucks (SBUX) and Dunkin Brands Group (DNKN). Print them out in a table.

# %%
#Couldn't find DNKN, so I replace it with PZZA

df1 = pd.read_csv("SBUX.csv").iloc[:, [0, 1]]
df2 = pd.read_csv("PZZA.csv").iloc[:, 1]

data = pd.concat([df1, df2], axis=1)
data.columns = ["Date", "SBUX", "PZZA"]
data.time = pd.to_datetime(data['Date'], format='%Y-%m-%d %H:%M:%S.%f')
data.set_index(['Date'],inplace=True)
data
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:8: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#                   SBUX       PZZA
# Date
# 2019-01-02   63.680000  39.639999
# 2019-01-03   63.459999  39.790001
# 2019-01-04   62.400002  40.700001
# 2019-01-07   63.349998  41.709999
# 2019-01-08   63.939999  43.049999
# 2019-01-09   63.650002  43.759998
# 2019-01-10   63.610001  42.490002
# 2019-01-11   62.290001  42.410000
# 2019-01-14   63.349998  42.419998
# 2019-01-15   63.580002  42.580002
# 2019-01-16   64.199997  42.290001
# 2019-01-17   63.680000  42.180000
# 2019-01-18   64.809998  43.099998
# 2019-01-22   64.900002  42.750000
# 2019-01-23   65.879997  41.889999
# 2019-01-24   66.610001  44.779999
# 2019-01-25   67.029999  45.930000
# 2019-01-28   66.190002  42.000000
# 2019-01-29   67.000000  42.599998
# 2019-01-30   67.110001  42.500000
# 2019-01-31   68.180000  42.240002
# 2019-02-01   68.589996  41.830002
# 2019-02-04   68.029999  41.389999
# 2019-02-05   67.760002  42.029999
# 2019-02-06   69.230003  43.799999
# 2019-02-07   68.599998  42.869999
# 2019-02-08   68.769997  42.959999
# 2019-02-11   70.000000  43.029999
# 2019-02-12   70.239998  44.029999
# 2019-02-13   69.809998  43.830002
# ...                ...        ...
# 2020-11-18   98.629997  78.279999
# 2020-11-19   97.239998  77.089996
# 2020-11-20   97.419998  78.889999
# 2020-11-23   97.620003  79.370003
# 2020-11-24   97.510002  81.589996
# 2020-11-25   98.500000  83.320000
# 2020-11-27   98.480003  80.529999
# 2020-11-30   98.199997  81.529999
# 2020-12-01   99.000000  80.860001
# 2020-12-02   98.510002  81.260002
# 2020-12-03   99.019997  80.059998
# 2020-12-04  101.349998  81.290001
# 2020-12-07  102.010002  81.050003
# 2020-12-08  100.370003  81.580002
# 2020-12-09  101.940002  85.400002
# 2020-12-10  103.510002  84.510002
# 2020-12-11  104.410004  83.739998
# 2020-12-14  103.830002  84.709999
# 2020-12-15  104.239998  86.620003
# 2020-12-16  104.099998  87.449997
# 2020-12-17  103.550003  87.489998
# 2020-12-18  103.330002  89.709999
# 2020-12-21  101.220001  89.250000
# 2020-12-22  102.120003  87.629997
# 2020-12-23  102.290001  86.400002
# 2020-12-24  102.300003  87.489998
# 2020-12-28  102.919998  87.930000
# 2020-12-29  104.889999  88.599998
# 2020-12-30  105.989998  85.910004
# 2020-12-31  106.000000  84.519997
#
# [505 rows x 2 columns]

# %% [markdown]
# ## b. Data Structure
# The data is returned to us as a pandas dataframe object. Index your data to convert them into simple strings.

# %%
data["SBUX"].head()
# Out:
# Date
# 2019-01-02    63.680000
# 2019-01-03    63.459999
# 2019-01-04    62.400002
# 2019-01-07    63.349998
# 2019-01-08    63.939999
# Name: SBUX, dtype: float64

# %% [markdown]
# ## c. Plotting
# Plot the data for SBUX stock price as a function of time. Remember to label your axis and title the graph.

# %%
plt.plot(data['SBUX']);
plt.xlabel('Time');
plt.ylabel('Price');
plt.title('Price vs Time');

# %% [markdown]
# ---

# %% [markdown]
# # Exercise 4 : Best fits plots
# Here we have a scatter plot of two data sets. Vary the `a`  and `b` parameter in the code to try to draw a line that 'fits' our data nicely. The line should seem as if it is describing a pattern in the data. *While quantitative methods exist to do this automatically, we would like you to try to get an intuition for what this feels like.*

# %%
data1 = pd.read_csv("SBUX.csv").iloc[:, 1]
data2 = pd.read_csv("SPY.csv").iloc[:, 1]

rdata1= data1.pct_change()[1:]
rdata2= data2.pct_change()[1:]
plt.scatter(rdata2, rdata1);

# %%
plt.scatter(rdata2, rdata1)

a = 0.0004
b = 1.14

x = np.arange(-0.02, 0.03, 0.01)
y = a + (b*x)
plt.plot(x,y, color='r');

# %% [markdown]
# ---
#
# Congratulations on completing the Plotting exercises!
#
# As you learn more about writing trading algorithms and the Quantopian platform, be sure to check out the daily [Quantopian Contest](https://www.quantopian.com/contest), in which you can compete for a cash prize every day.
#
# Start by going through the [Writing a Contest Algorithm](https://www.quantopian.com/tutorials/contest) tutorial.

# %% [markdown]
# *This presentation is for informational purposes only and does not constitute an offer to sell, a solicitation to buy, or a recommendation for any security; nor does it constitute an offer to provide investment advisory or other services by Quantopian, Inc. ("Quantopian"). Nothing contained herein constitutes investment advice or offers any opinion with respect to the suitability of any security, and any views expressed herein should not be taken as advice to buy, sell, or hold any security or as an endorsement of any security or company.  In preparing the information contained herein, Quantopian, Inc. has not taken into account the investment needs, objectives, and financial circumstances of any particular investor. Any views expressed and data illustrated herein were prepared based upon information, believed to be reliable, available to Quantopian, Inc. at the time of publication. Quantopian makes no guarantees as to their accuracy or completeness. All information is subject to change and may quickly become unreliable for various reasons, including changes in market conditions or economic circumstances.*
